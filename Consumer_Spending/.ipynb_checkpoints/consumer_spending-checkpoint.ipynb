# %% [markdown]
# **Documenting Consumer Spendings**
#
# Consumer spendings will be determined by the csv file, Percent_Change_in_Consumer_Spending.csv. First we will show the
# top part of the data to confirm with what part we be using.

# %%
import pandas as pd

consumer_spending = pd.read_csv('Percent_Change_in_Consumer_Spending.csv')

consumer_spending.head(10)
# Out:
#    State FIPS code        Date  All merchant category codes spending  \
# 0              900  01/13/2020                               -1.7600
# 1             2500  01/13/2020                               -0.2200
# 2             3400  01/13/2020                               -0.5600
# 3             3600  01/13/2020                               -0.3730
# 4             4400  01/13/2020                               -1.8500
# 5              900  01/14/2020                                0.6330
# 6             2500  01/14/2020                                1.2400
# 7             3400  01/14/2020                                0.8900
# 8             3600  01/14/2020                                0.4270
# 9             4400  01/14/2020                                0.0824
#
#    Accommodation and food service (ACF) spending  \
# 0                                          -5.43
# 1                                          -2.47
# 2                                          -3.86
# ...

# %% [markdown]
# Checking the dataset info.

# %%
consumer_spending.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4730 entries, 0 to 4729
# Data columns (total 11 columns):
#  #   Column                                                                       Non-Null Count  Dtype
# ---  ------                                                                       --------------  -----
#  0   State FIPS code                                                              4730 non-null   int64
#  1   Date                                                                         4730 non-null   object
#  2   All merchant category codes spending                                         4730 non-null   float64
#  3   Accommodation and food service (ACF) spending                                4730 non-null   float64
#  4   Arts, entertainment, and recreation (AER)  spending                          4730 non-null   float64
#  5   General merchandise stores (GEN) and apparel and accessories (AAP) spending  4730 non-null   float64
# ...

# %% [markdown]
# Check for null values.

# %%
consumer_spending.isnull().sum()
# Out:
# State FIPS code                                                                0
# Date                                                                           0
# All merchant category codes spending                                           0
# Accommodation and food service (ACF) spending                                  0
# Arts, entertainment, and recreation (AER)  spending                            0
# General merchandise stores (GEN) and apparel and accessories (AAP) spending    0
# Grocery and food store (GRF)  spending                                         0
# Health care and social assistance (HCS) spending                               0
# Transportation and warehousing (TWS)  spending                                 0
# Retail spending, including grocery  (AAP, CEC, GEN, GRF, HIC, ETC, SGH)        0
# Retail spending, excluding grocery ((AAP, CEC, GEN, HIC, ETC, SGH)             0
# dtype: int64

# %% [markdown]
# There are no null values hence data can be used.

# %% [markdown]
# We have to know how many different fips codes are there in the dataset.

# %%
consumer_spending['State FIPS code'].unique()
# Out:
# array([ 900, 2500, 3400, 3600, 4400])

# %% [markdown]
# We will only be using the above 5 FIPS codes.

# %% [markdown]
# This shows that the data is for the whole year of 01-13-2020 to 10-15-2023.
# This can help to predict future consumer spending.

# %% [markdown]
# **Line Graph of Merchant Category Spending**
#
# Using the All Merchant Category codes spending column we will plot a line graph to see the trend of consumer spending.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

consumer_spending['Date'] = pd.to_datetime(consumer_spending['Date'],
                                           format='mixed')

plt.figure(figsize=(15,8))

sns.lineplot(x = 'Date',y ='All merchant category codes spending',
             data= consumer_spending, color='red')

plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
plt.xticks(rotation=45)

plt.title('Percentage of Merchant Category Codes Spending', fontsize=15,
          fontweight='bold')
plt.xlabel('Date', fontsize=12, fontweight='bold')
plt.ylabel('Spending', fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# There was a huge drop in consumer spending in April 2020. This was due to
# the lockdowns imposed by the government to curb the spread of COVID-19
# virus. People had to adopt a new way of trading hence an increase in
# April to December 2020. The trend has been constantly increasing since
# January 2021.

# %% [markdown]
# **Line plot for Accommodation and Food Services Spending**
#
# We will plot a line graph to see the trend of consumer spending in the
# Accommodation and Food Services sector.

# %%
plt.figure(figsize=(15,8))

sns.lineplot(x = 'Date',y ='Accommodation and food service (ACF) spending',
             data= consumer_spending, color='blue')

plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
plt.xticks(rotation=45)

plt.title('Percentage of Accommodation and Food Services Spending',
          fontsize=15, fontweight='bold')
plt.xlabel('Date', fontsize=12, fontweight='bold')
plt.ylabel('Spending', fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# Here also we can see there was a huge drop in consumer spending in March to
# April 2020.Actually the whole of 2020 was a bad year for the Accommodation
# and Food Services sector. The trend has been increasing since January 2021.

# %% [markdown]
# **Arts, Entertainment, and Recreation Spending**
#
# We will plot a line graph to see the trend of consumer spending in the
# Arts, Entertainment, and Recreation sector.

# %%
plt.figure(figsize=(15,8))

sns.lineplot(x= 'Date', y='Arts, entertainment, and recreation (AER) spending',
             data= consumer_spending, color='green')

plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
plt.xticks(rotation=45)

plt.title('Percentage of Arts, Entertainment, and Recreation Spending',
          fontsize=15, fontweight='bold')
plt.xlabel('Date', fontsize=12, fontweight='bold')
plt.ylabel('Spending', fontsize=12, fontweight='bold')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 plt.figure(figsize=(15,8))
# ----> 3 sns.lineplot(x= 'Date', y='Arts, entertainment, and recreation (AER) spending',
#       4              data= consumer_spending, color='green')
#       6 plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
#       7 plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
#
# File ~/Documents/lib/python3.11/site-packages/seaborn/relational.py:479, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     465 def lineplot(
#     466     data=None, *,
#     467     x=None, y=None, hue=None, size=None, style=None, units=None,
#    (...)
#     475
# ...
